# %% [markdown]
# Diabetes Risk Prediction (Using TensorFlow FrameWork)
#
# Neural Network Architecture
# 2 inputs -> 3 Hidden Neurons(sigmoid) ->1 Output

# %%
import numpy as np
import tensorflow as tf

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1822/3978472338.py in <cell line: 0>()
#       1 import numpy as np
# ----> 2 import tensorflow as tf
#       3
#       4 from tensorflow.keras.layers import Dense
#       5 from tensorflow.keras.models import Sequential
#
# ModuleNotFoundError: No module named 'tensorflow'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
X=np.array([
    {120,25},
    [85,30],
    [150,35],
    [95,22]
])

X=X/200
Y=np.array([1,0,1,0])
print("Input Shape: ",X.shape)
print("Output Shape: ",Y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1822/55100583.py in <cell line: 0>()
# ----> 1 X=np.array([
#       2     {120,25},
#       3     [85,30],
#       4     [150,35],
#       5     [95,22]
#
# NameError: name 'np' is not defined

# %% [markdown]
# Train  the model

# %%
model.fit(X,Y,epochs=500,verbose=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1822/2286101492.py in <cell line: 0>()
# ----> 1 model.fit(X,Y,epochs=500,verbose=0)
#       2
#
# NameError: name 'model' is not defined

# %% [markdown]
# Make Predictions

# %%
predictions=model.predict(X)
print("Predictions: ")
print(predictions)
